# %%
# !pip install rpy2==3.5.1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.7/201.7 kB 6.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for rpy2: filename=rpy2-3.5.1-cp310-cp310-linux_x86_64.whl size=318087 sha256=036d5f6456a95d09a98cde2b5cea1fcd873b2945b4e89938131011aeb4780ab8
#   Stored in directory: /root/.cache/pip/wheels/73/a6/ff/4e75dd1ce1cfa2b9a670cbccf6a1e41c553199e9b25f05d953
# Successfully built rpy2
# ...
#   Attempting uninstall: rpy2
#     Found existing installation: rpy2 3.5.5
#     Uninstalling rpy2-3.5.5:
#       Successfully uninstalled rpy2-3.5.5
# ...

# %%
# activate R magic
# %load_ext rpy2.ipython

# %%
# %%R
# print("Welcome to Codic Solution")
# Out:
# [1] "Welcome to Codic Solution"

# %%
# %%R
# # create a vector of numbers from 1 to 5
# numbers <- 1:5
#
# # loop over the vector and print the squares of each number
# for (n in numbers) {
#   square <- n^2
#   print(paste("The square of", n, "is", square))
# }
# Out:
# [1] "The square of 1 is 1"
# [1] "The square of 2 is 4"
# [1] "The square of 3 is 9"
# [1] "The square of 4 is 16"
# [1] "The square of 5 is 25"
